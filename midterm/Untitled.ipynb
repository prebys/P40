# %%
a = 9949499459584903845049034905903494934399999998899989998999997262763839494
b = 494930930390
print(a+b)
# Out:
# 9949499459584903845049034905903494934399999998899989998999997757694769884

# %%
import numpy as np
arr = np.array([a,b])
print(arr)
# Out:
# [9949499459584903845049034905903494934399999998899989998999997262763839494
#  494930930390]

# %%
a = 3.
b = 1e-17
print(a+b)
# Out:
# 3.0

# %%
a = 2e200
b = 3e180
print(a+b)
# Out:
# 2e+200

# %%
print(a*b)
# Out:
# inf
