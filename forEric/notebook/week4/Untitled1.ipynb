# %%
import numpy as np

def isprime(num):
    if num%2 != 0:
        return True
    else:
        return False

# %%
n = 0 
i = 0
while n < 5:
    print(i,n)
    if isprime(i):
        n = n+1
    i = i + 1
# Out:
# 0 0
# 1 0
# 2 1
# 3 1
# 4 2
# 5 2
# 6 3
# 7 3
# 8 4
# 9 4

# %%
import numpy as np
# %pylab inline
from matplotlib import pylab as plt
plt.ion()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
def polinomialfunction(x,coeff):
    y = 0
    for j,k in enumerate(coeff):
        print(i,j)
        y = y + j * x **k
    return y
x=np.arange(100)

y = polinomialfunction(x,[1,1,1,1])


plt.plot(x,y)
# Out:
# 10 0
# 10 1
# 10 2
# 10 3

# %%
wands = {
    'Wood':'yew',
    'Length':13.5
}
wands['core'] = 'Phoenix Feather'
print('The wands core is ',wands['core'])
# Out:
# The wands core is  Phoenix Feather
