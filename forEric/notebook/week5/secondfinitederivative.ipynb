# %% [markdown]
# # using second finite derivative to compute temperature propagation with laplace equation

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set maximum iteration
maxIter = 500

# Set Dimension and delta
lenX = 40
lenY = 20 #we set it rectangular
delta = 1

# %%
# Boundary condition
Ttop = 100
Tbottom = 0
Tleft = 30
Tright = 0

# Initial guess of interior grid
Tguess = 130

# Set colour interpolation and colour map
colorinterpolation = 50
colourMap = plt.cm.jet #you can try: colourMap = plt.cm.coolwarm

# Set meshgrid
X, Y = np.meshgrid(np.arange(0, lenX), np.arange(0, lenY))

# %%
# Set array size and set the interior value with Tguess
T = np.empty((lenX, lenY))
T.fill(Tguess)

# %%
# Set Boundary condition
T[(lenY-1):, :] = Ttop
T[:1, :] = Tbottom
T[:, (lenX-1):] = Tright
T[:, :1] = Tleft

# %%
# Iteration (We assume that the iteration is convergence in maxIter = 500)
print("Please wait for a moment")
for iteration in range(0, maxIter):
    for i in range(1, lenX-1, delta):
        for j in range(1, lenY-1, delta):
            T[i, j] = 0.25 * (T[i+1][j] + T[i-1][j] + T[i][j+1] + T[i][j-1])
# Out:
# Please wait for a moment

# %%
print("Iteration finished")

# Configure the contour
plt.title("Contour of Temperature")
plt.contourf(X, Y, T, colorinterpolation, cmap=colourMap)

# Set Colorbar
plt.colorbar()

# Show the result in the plot window
plt.show()

print("")
# Out:
# Iteration finished
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 # Configure the contour
#       4 plt.title("Contour of Temperature")
# ----> 5 plt.contourf(X, Y, T, colorinterpolation, cmap=colourMap)
#       7 # Set Colorbar
#       8 plt.colorbar()
#
# File /opt/anaconda3/envs/phy40/lib/python3.13/site-packages/matplotlib/pyplot.py:3190, in contourf(data, *args, **kwargs)
#    3188 @_copy_docstring_and_deprecators(Axes.contourf)
#    3189 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 3190     __ret = gca().contourf(
#    3191         *args, **({"data": data} if data is not None else {}), **kwargs
#    3192     )
#    3193     if __ret._A is not None:  # type: ignore[attr-defined]
#    3194         sci(__ret)
#
# File /opt/anaconda3/envs/phy40/lib/python3.13/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/envs/phy40/lib/python3.13/site-packages/matplotlib/axes/_axes.py:6797, in Axes.contourf(self, *args, **kwargs)
#    6786 """
#    6787 Plot filled contours.
#    6788
#    (...)   6794 %(contour_doc)s
#    6795 """
#    6796 kwargs['filled'] = True
# -> 6797 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6798 self._request_autoscale_view()
#    6799 return contours
#
# File /opt/anaconda3/envs/phy40/lib/python3.13/site-packages/matplotlib/contour.py:701, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     697 if self.negative_linestyles is None:
#     698     self.negative_linestyles = \
#     699         mpl.rcParams['contour.negative_linestyle']
# --> 701 kwargs = self._process_args(*args, **kwargs)
#     702 self._process_levels()
#     704 self._extend_min = self.extend in ['min', 'both']
#
# File /opt/anaconda3/envs/phy40/lib/python3.13/site-packages/matplotlib/contour.py:1319, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1316         corner_mask = mpl.rcParams['contour.corner_mask']
#    1317 self._corner_mask = corner_mask
# -> 1319 x, y, z = self._contour_args(args, kwargs)
#    1321 contour_generator = contourpy.contour_generator(
#    1322     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1323     line_type=contourpy.LineType.SeparateCode,
#    1324     fill_type=contourpy.FillType.OuterCode,
#    1325     chunk_size=self.nchunk)
#    1327 t = self.get_transform()
#
# File /opt/anaconda3/envs/phy40/lib/python3.13/site-packages/matplotlib/contour.py:1359, in QuadContourSet._contour_args(self, args, kwargs)
#    1357 elif 2 < nargs <= 4:
#    1358     x, y, z_orig, *args = args
# -> 1359     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1361 else:
#    1362     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File /opt/anaconda3/envs/phy40/lib/python3.13/site-packages/matplotlib/contour.py:1406, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1404 elif x.ndim == 2:
#    1405     if x.shape != z.shape:
# -> 1406         raise TypeError(
#    1407             f"Shapes of x {x.shape} and z {z.shape} do not match")
#    1408     if y.shape != z.shape:
#    1409         raise TypeError(
#    1410             f"Shapes of y {y.shape} and z {z.shape} do not match")
#
# TypeError: Shapes of x (20, 40) and z (40, 20) do not match
