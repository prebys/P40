# %%
class Employee:
    def __init__(self,first,last,pay):
        self.first = first
        self.last = last
        self.pay = pay

    def fullname(self):
        return '{} {}'.format(emp1.first,emp1.last)
    
emp1= Employee('Mark','Green','3000')
emp2= Employee('test','test','5000')

print(emp1)
print(emp2)

# %%
print(emp1.first)
print(emp1.last)
print(emp1.pay)
# Out:
# Mark
# Green
# 3000

# %%
print('{} {}'.format(emp1.first,emp1.last))

emp1.fullname()
# Out:
# Mark Green
# 'Mark Green'

# %%
def nPrint(message, n):
    while n > 0:
        print(message)
        n -= 1

# %%
nPrint('a',4)
# Out:
# a
# a
# a
# a

# %%
25+12
# Out:
# 37
