# %% [markdown]
# # Simple examples for Lecture 1

# %%
# Add two numbers
a = 5
b = 7
print(a+b)

# %%
# Define a routine to add two numbers
def sum(a,b):
    c = a+b
    return c

# %%
# Call the routine I just created
x= 5
y = 12
z = sum(x,y)
print(z)
