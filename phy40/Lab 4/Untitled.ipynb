# %%
import numpy as np
import math
import cmath

# %%
def simplify(a,b):
    i = 1
    while i<=min(a,b):
        if (a%i==0) and (b%i==0):
            a //= i
            b //= i
        i += 1
    return a,b

# %%
print (reduce(3,11))
# Out:
# (3, 11)

# %%
a = cmath.sqrt(1)
print(a)

# %%
a,b = simplify(3,12)
print("{}/{}".format(a,b))
# Out:
# 1/4
